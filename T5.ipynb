# %%
import random
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
import torch.nn as nn

from transformers import T5Tokenizer, T5ForConditionalGeneration, get_scheduler

import regex
import json
import string
from tqdm.auto import tqdm
import numpy as np
import collections

from torch.utils.tensorboard import SummaryWriter
# %load_ext tensorboard

# %%
# MODEL_NAME = 't5-base'
# MODEL_NAME = "NlpHUST/t5-en-vi-small"
MODEL_NAME = "VietAI/vit5-base"
SOURCE_MAX_LEN = 256
TARGET_MAX_LEN = 64
BATCH_SIZE = 32


device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
device
# Out:
# device(type='cuda')

# %%
checkpoint_name = 'ViT5-UIT-ViQuAD-1'
checkpoint_path = f"checkpoints/{checkpoint_name}"
os.makedirs(checkpoint_path, exist_ok=True)

# %%
writer = SummaryWriter(f'runs/{checkpoint_name}')

# %% [markdown]
# # Dataset

# %%
class ODQADataset(Dataset):
    def __init__(self, data_path, n_context=1):
        self.data = []
        with open(data_path, 'r') as f:
            data = json.load(f)
            for qa in data:
                if len(qa['contexts'][:n_context]) != 0:
                    self.data.append(qa)
        self.n_context = n_context
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        sample = self.data[idx]
       
        source = [f"question: {sample['question']} context: {ctx.replace('_', ' ')}" for ctx in sample['contexts'][:self.n_context]]
        target = random.choice(sample['answers'])['text']
        
        return {'index': idx,
                'source': source,
                'target': target}

# %%
class Collator:
    def __init__(self, tokenizer, source_max_length, target_max_length):
        self.tokenizer = tokenizer
        self.source_max_length = source_max_length
        self.target_max_length = target_max_length
    
    def __call__(self, batch):
        indices = torch.tensor([sample['index'] for sample in batch])
        
        sources = [sample['source'] for sample in batch]
        sources_encoding = self.__encode_sources_batch__(sources)
        sources_ids = sources_encoding['input_ids']
        sources_masks = sources_encoding['attention_mask'].bool()
        
        targets = [sample['target'] for sample in batch]
        targets_encoding = self.tokenizer.batch_encode_plus(
            targets, 
            max_length=self.target_max_length,
            add_special_tokens=True, 
            padding='max_length',
            truncation=True,
            return_tensors='pt'
            )
        
        targets_ids = targets_encoding['input_ids']
        targets_masks = targets_encoding['attention_mask'].bool()
        targets_ids = targets_ids.masked_fill(~targets_masks, -100)
        
        return indices, sources_ids, sources_masks, targets_ids, targets_masks
    
    def __encode_sources_batch__(self, sources_batch):
        input_ids, attention_mask = [], []
        for sources in sources_batch:
            encoding = self.tokenizer.batch_encode_plus(
                sources, 
                max_length=self.source_max_length,
                add_special_tokens=True, 
                padding='max_length',
                truncation=True,
                return_tensors='pt'
            )
            input_ids.append(encoding['input_ids'][None])
            attention_mask.append(encoding['attention_mask'][None])
        
        input_ids = torch.cat(input_ids, dim=0)
        attention_mask = torch.cat(attention_mask, dim=0)
        
        return {'input_ids': input_ids, 'attention_mask': attention_mask}

# %%
tokenizer = T5Tokenizer.from_pretrained(MODEL_NAME)
collate_fn = Collator(tokenizer, SOURCE_MAX_LEN, TARGET_MAX_LEN)

# %% [markdown]
# # Model

# %%
class CheckpointWrapper(torch.nn.Module):
    """
    Wrapper replacing None outputs by empty tensors, which allows the use of
    checkpointing.
    """
    def __init__(self, module, use_checkpoint=False):
        super().__init__()
        self.module = module
        self.use_checkpoint = use_checkpoint

    def forward(self, hidden_states, attention_mask, position_bias, **kwargs):
        if self.use_checkpoint and self.training:
            kwargs = {k: v for k, v in kwargs.items() if v is not None}
            def custom_forward(*inputs):
                output = self.module(*inputs, **kwargs)
                empty = torch.tensor(
                    [],
                    dtype=torch.float,
                    device=output[0].device,
                    requires_grad=True)
                output = tuple(x if x is not None else empty for x in output)
                return output

            output = torch.utils.checkpoint.checkpoint(
                custom_forward,
                hidden_states,
                attention_mask,
                position_bias
            )
            output = tuple(x if x.size() != 0 else None for x in output)
        else:
            output = self.module(hidden_states, attention_mask, position_bias, **kwargs)
        return output
    
def apply_checkpoint_wrapper(t5stack, use_checkpoint):
    """
    Wrap each block of the encoder to enable checkpointing.
    """
    block = []
    for mod in t5stack.block:
        wrapped_mod = CheckpointWrapper(mod, use_checkpoint)
        block.append(wrapped_mod)
    block = nn.ModuleList(block)
    t5stack.block = block

# %%
class MultipleInputsT5(T5ForConditionalGeneration):
    def __init__(self, config):
        super().__init__(config)        
        # self.wrap_encoder()

    # We need to resize as B x (N * L) instead of (B * N) x L here
    # because the T5 forward method uses the input tensors to infer
    # dimensions used in the decoder.
    def forward(self, input_ids=None, attention_mask=None, **kwargs):
        if input_ids != None:
            # inputs might have already be resized in the generate method
            if input_ids.dim() == 3:
                self.encoder.n_passages = input_ids.size(1)
            input_ids = input_ids.view(input_ids.size(0), -1)
        if attention_mask != None:
            attention_mask = attention_mask.view(attention_mask.size(0), -1)
        return super().forward(
            input_ids=input_ids,
            attention_mask=attention_mask,
            **kwargs
        )
        
    def generate(self, input_ids, attention_mask, max_length):
        self.encoder.n_passages = input_ids.size(1)
        return super().generate(
            input_ids=input_ids.view(input_ids.size(0), -1),
            attention_mask=attention_mask.view(attention_mask.size(0), -1),
            max_length=max_length
        )
        
            
    def wrap_encoder(self, use_checkpoint=False):
        """
        Wrap T5 encoder to obtain a Fusion-in-Decoder model.
        """
        self.encoder = WrappedEncoder(self.encoder, use_checkpoint=use_checkpoint)
    
    def unwrap_encoder(self):
        """
        Unwrap Fusion-in-Decoder encoder, useful to load T5 weights.
        """
        self.encoder = self.encoder.encoder
        block = []
        for mod in self.encoder.block:
            block.append(mod.module)
        block = nn.ModuleList(block)
        self.encoder.block = block
        
    def load_t5(self, state_dict):
        self.unwrap_encoder()
        self.load_state_dict(state_dict)
        self.wrap_encoder()
        
class WrappedEncoder(torch.nn.Module):
    """
    Encoder Wrapper for T5 Wrapper to obtain a Fusion-in-Decoder model.
    """
    def __init__(self, encoder, use_checkpoint=False):
        super().__init__()

        self.encoder = encoder
        self.main_input_name = encoder.main_input_name
        apply_checkpoint_wrapper(self.encoder, use_checkpoint)

    def forward(self, input_ids=None, attention_mask=None, **kwargs,):
        # total_length = n_passages * passage_length
        batch_sz, total_length = input_ids.shape
        passage_length = total_length // self.n_passages
        input_ids = input_ids.view(batch_sz * self.n_passages, passage_length)
        attention_mask = attention_mask.view(batch_sz * self.n_passages, passage_length)
        outputs = self.encoder(input_ids, attention_mask, **kwargs)
        outputs = (outputs[0].view(batch_sz, self.n_passages * passage_length, -1), ) + outputs[1:]
        return outputs

# %% [markdown]
# # Fine-tuning

# %%
train_set = ODQADataset('data/ViQuAD/train_viquad.json', n_context=10)

# %%
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)

# %% [markdown]
# ## Model

# %%
model = MultipleInputsT5.from_pretrained(MODEL_NAME).to(device)

# %%
num_epochs = 2
num_training_steps = num_epochs * len(train_loader)
optimizer = AdamW(model.parameters(), lr=5e-5)
lr_scheduler = get_scheduler(name='linear', optimizer=optimizer, num_warmup_steps=1000, num_training_steps=num_training_steps)

# %%
progress_bar = tqdm(range(num_training_steps))

verbose_step = 50
checkpoint_step = 5000
model.train()
step = 0
for epoch in range(num_epochs):
    print(f'Epoch {epoch}:')
    for iter, batch in enumerate(train_loader):
        _, sources_ids, sources_masks, targets_ids, targets_masks = batch
        
        outputs = model(
            input_ids=sources_ids.to(device),
            attention_mask=sources_masks.to(device),
            labels=targets_ids.to(device)
        )
        loss = outputs.loss
        loss.backward()
        lr = lr_scheduler.get_lr()[0]
        
        optimizer.step()
        lr_scheduler.step()
        optimizer.zero_grad()
        progress_bar.update(1)
        
        step += 1
        if step % verbose_step == 0:
            print(f'### Iter: {step} - Learning rate: {round(lr, 10)} - Loss: {round(loss.item(), 10)}')
            writer.add_scalar('Learning rate', lr, step)
            writer.add_scalar('Loss', loss.item(), step)
            
        if step % checkpoint_step == 0:
            torch.save({
                'epoch': epoch,
                'optimizer': optimizer.state_dict(),
                'scheduler': lr_scheduler.state_dict(),
                'model': model.state_dict(),
            }, f'checkpoints/{checkpoint_name}/checkpoint_iter{step}.pth')
            model.save_pretrained(f'checkpoints/{checkpoint_name}/model_iter{step}')

torch.save({
    'epoch': epoch,
    'optimizer': optimizer.state_dict(),
    'scheduler': lr_scheduler.state_dict(),
    'model': model.state_dict(),
}, f'checkpoints/{checkpoint_name}/checkpoint_final.pth')
model.save_pretrained(f'checkpoints/{checkpoint_name}/model_final')
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=37154.0), HTML(value='')))
# Epoch 0:
# ### Iter: 50 - Learning rate: 2.45e-06 - Loss: 5.5834293365
# ### Iter: 100 - Learning rate: 4.95e-06 - Loss: 16.8477725983
# ### Iter: 150 - Learning rate: 7.45e-06 - Loss: 1.9185131788
# ### Iter: 200 - Learning rate: 9.95e-06 - Loss: 3.182046175
# ### Iter: 250 - Learning rate: 1.245e-05 - Loss: 3.7116234303
# ### Iter: 300 - Learning rate: 1.495e-05 - Loss: 1.5477397442
# ### Iter: 350 - Learning rate: 1.745e-05 - Loss: 0.7607566118
# ### Iter: 400 - Learning rate: 1.995e-05 - Loss: 3.6523406506
# ### Iter: 450 - Learning rate: 2.245e-05 - Loss: 2.2885518074
# ### Iter: 500 - Learning rate: 2.495e-05 - Loss: 4.9177060127
# ### Iter: 550 - Learning rate: 2.745e-05 - Loss: 1.3733707666
# ### Iter: 600 - Learning rate: 2.995e-05 - Loss: 6.1418886185
# ### Iter: 650 - Learning rate: 3.245e-05 - Loss: 0.7553626299
# ### Iter: 700 - Learning rate: 3.495e-05 - Loss: 1.6045964956
# ### Iter: 750 - Learning rate: 3.745e-05 - Loss: 0.783010006
# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Utilities

# %%
def normalize_text(s):
    def remove_articles(text):
        return regex.sub(r'\b(a|an|the)\b', ' ', text)

    def white_space_fix(text):
        return ' '.join(text.split())

    def remove_punc(text):
        exclude = set(string.punctuation)
        return ''.join(ch for ch in text if ch not in exclude)

    def lower(text):
        return text.lower()

    text = white_space_fix(remove_articles(remove_punc(lower(s))))
    return text

def exact_match_score(prediction, ground_truth):
    return normalize_text(prediction) == normalize_text(ground_truth)

def ems(prediction, ground_truths):
    return max([exact_match_score(prediction, gt) for gt in ground_truths])

def compute_f1(prediction, truth):
    pred_tokens = normalize_text(prediction).split()
    truth_tokens = normalize_text(truth).split()
    
    # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
    if len(pred_tokens) == 0 or len(truth_tokens) == 0:
        return int(pred_tokens == truth_tokens)
    
    common_tokens = collections.Counter(pred_tokens) & collections.Counter(truth_tokens)
    
    n_common_tokens = sum(common_tokens.values())
    
    if n_common_tokens == 0:
        return 0
    
    prec = n_common_tokens / len(pred_tokens)
    rec = n_common_tokens / len(truth_tokens)
    
    return 2 * (prec * rec) / (prec + rec)

def compute_f1_all(prediction, ground_truths):
    return max([compute_f1(prediction, gt) for gt in ground_truths])

# %%
model = MultipleInputsT5.from_pretrained(f'{checkpoint_path}/model_final').to(device)

# %%
test_set = ODQADataset('data/ViQuAD/test_ViQuAD_converted.json', 1)

# %%
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, collate_fn=collate_fn)

# %%
model.eval()

exact_match = []
f1 = []
total = 0
progress_bar = tqdm(range(len(test_loader)))
result = []
with torch.no_grad():
    for i, batch in enumerate(test_loader):
        idx, context_ids, context_masks, _, _, = batch

        outputs = model.generate(
            input_ids=context_ids.to(device),
            attention_mask=context_masks.to(device),
            max_length=50,
        )

        for k, o in enumerate(outputs):
            predict = tokenizer.decode(o, skip_special_tokens=True)
            sample = test_set.data[idx[k]]
            ground_truths = [ans['text'] for ans in sample['answers']]
            em_score = ems(predict, ground_truths)
            f1_score = compute_f1_all(predict, ground_truths)
            result.append({
                'question': sample['question'],
                'predict': predict,
                'ground_truths': ground_truths,
                'em_score': em_score,
                'f1_score': f1_score,
                })
            exact_match.append(em_score)
            f1.append(f1_score)
            total += 1
        
        progress_bar.update(1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=70.0), HTML(value='')))

# %%
em_score = np.mean(exact_match)
print(em_score)
# Out:
# 0.5235294117647059

# %%
f1_score = np.mean(f1)
f1_score
# Out:
# 0.747181659068327

# %% [markdown]
# Ground truth only: 0.42036199095022625 0.6388585316330179

# %% [markdown]
# top10: em: 0.36334841628959275, f1: 0.5881111813897126

# %%
result
# Out:
# [{'question': 'Cộng hòa Weimar chính thức thay thế đế quốc Đức kể từ sau sự kiện nào?',
#   'predict': 'Chiến tranh thế giới thứ nhất và Cách mạng Đức 1918-1919',
#   'ground_truths': ['Chiến tranh thế giới thứ nhất và Cách mạng Đức 1918-1919',
#    'Chiến tranh thế giới thứ nhất và Cách mạng Đức 1918-1919',
#    'Chiến tranh thế giới thứ nhất và Cách mạng Đức 1918-1919',
#    'Chiến tranh thế giới thứ nhất và Cách mạng Đức 1918-1919'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nước Đức hiện nay sự hợp thành của hai nước nào trong thời kỳ Đồng minh chiếm đóng Đức?',
#   'predict': 'Cộng hòa Liên bang Đức và Cộng hòa Dân chủ Đức',
#   'ground_truths': ['Cộng hòa Liên bang Đức và Cộng hòa Dân chủ Đức',
#    'Cộng hòa Liên bang Đức và Cộng hòa Dân chủ Đức',
#    'Cộng hòa Liên bang Đức và Cộng hòa Dân chủ Đức',
#    'Cộng hòa Liên bang Đức và Cộng hòa Dân chủ Đức'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Hậu quả nào đã xảy ra khi tại Đức chế độ độc tài quốc xã được hình thành?',
#   'predict': 'chiến tranh thế giới thứ hai và một nạn diệt chủng',
#   'ground_truths': ['Chiến tranh thế giới thứ hai và một nạn diệt chủng',
#    'Chiến tranh thế giới thứ hai và một nạn diệt chủng',
#    'Chiến tranh thế giới thứ hai và một nạn diệt chủng',
#    'Chiến tranh thế giới thứ hai và một nạn diệt chủng'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Cộng hòa Liên bang Đức và Cộng hòa Dân chủ Đức chính thức sát nhập vào năm nào?',
#   'predict': 'năm 1990',
#   'ground_truths': ['Năm 1990', '1990', 'Năm 1990', 'Năm 1990'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vào năm 2015, cả hai lĩnh vực nào Đức đều xếp ở vị trí thứ ba thế giới?',
#   'predict': 'công nghiệp và công nghệ',
#   'ground_truths': ['xuất khẩu và nhập khẩu',
#    'xuất khẩu và nhập khẩu',
#    'xuất khẩu và nhập khẩu',
#    'xuất khẩu và nhập khẩu'],
#   'em_score': False,
#   'f1_score': 0.20000000000000004},
#  {'question': 'Trên bảng danh sách các nước có nền kinh tế lớn nhất theo tiêu chí GDP thì vị trí thứ tư thuộc về nước nào?',
#   'predict': 'Hoa Kỳ',
#   'ground_truths': ['Đức', 'Đức', 'Đức', 'Đức'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Xã hội Đức như thế nào mà đã có thể duy trì được một tiêu chuẩn sinh hoạt rất cao?',
#   'predict': 'một xã hội có kỹ năng và năng suất',
#   'ground_truths': ['có kỹ năng và năng suất',
#    'một xã hội có kỹ năng và năng suất',
#    'nhờ một xã hội có kỹ năng và năng suất',
#    'có kỹ năng và năng suất'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Để Đức có thể trụ vững là một đất nước phát triển có tiêu chuẩn sinh hoạt cao thì chính quyền liên bang đã làm gì?',
#   'predict': 'duy trì một hệ thống an ninh xã hội và chăm sóc y tế phổ quát, bảo vệ môi trường và giáo dục đại học miễn học phí',
#   'ground_truths': ['duy trì một hệ thống an ninh xã hội và chăm sóc y tế phổ quát, bảo vệ môi trường và giáo dục đại học miễn học phí',
#    'duy trì một hệ thống an ninh xã hội và chăm sóc y tế phổ quát, bảo vệ môi trường và giáo dục đại học miễn học phí',
#    'duy trì một hệ thống an ninh xã hội và chăm sóc y tế phổ quát, bảo vệ môi trường và giáo dục đại học miễn học phí',
#    'duy trì một hệ thống an ninh xã hội và chăm sóc y tế phổ quát, bảo vệ môi trường và giáo dục đại học miễn học phí'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nếu tính theo sức mua thì nền kinh tế của Đức hiện nay đang đứng thứ mấy trong bảng xếp hạng toàn cầu?',
#   'predict': 'thứ ba',
#   'ground_truths': ['thứ năm', 'thứ năm', 'thứ năm', 'thứ năm'],
#   'em_score': False,
#   'f1_score': 0.5},
#  {'question': 'Trước khi thuật ngữ Deutschland được sử dụng thì trước đó thuật ngữ nào được dùng?',
#   'predict': 'tiếng Frisia',
#   'ground_truths': ['diutisciu land',
#    'diutisciu land',
#    'diutisciu land',
#    'diutisciu land'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Nghĩa của từ diutisciu land là gì?',
#   'predict': 'các vùng người Đức',
#   'ground_truths': ['các vùng người Đức',
#    'các vùng người Đức',
#    '"các vùng người Đức"',
#    'các vùng người Đức'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nguồn gốc của từ Germany trong tiếng anh là từ đâu?',
#   'predict': 'tiếng Germany trong tiếng Latinh',
#   'ground_truths': ['Germania trong tiếng Latinh',
#    'Germania trong tiếng Latinh',
#    'Germania trong tiếng Latinh',
#    'Germania trong tiếng Latinh'],
#   'em_score': False,
#   'f1_score': 0.6666666666666665},
#  {'question': 'Các dân tộc được Julius Caesar dùng từ Germany để gọi có khu vực sinh sống tại đâu?',
#   'predict': 'phía đông sông Rhine',
#   'ground_truths': ['phía đông sông Rhine',
#    'phía đông sông Rhine',
#    'phía đông sông Rhine',
#    'phía đông sông Rhine'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Từ *þiudiskaz trong tiếng German nguyên thủy có nghĩa là gì?',
#   'predict': 'dân',
#   'ground_truths': ['dân', 'dân', '"dân"', 'dân'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Qua sự kiện nào mà loài người phát hiện được vào 600.000 năm trước nước Đức đã có sự hiện diện của người cổ đại?',
#   'predict': 'việc phát hiện di cốt Mauer',
#   'ground_truths': ['phát hiện Di cốt Mauer',
#    'phát hiện Di cốt Mauer',
#    'phát hiện Di cốt Mauer',
#    'phát hiện Di cốt Mauer'],
#   'em_score': False,
#   'f1_score': 0.9090909090909091},
#  {'question': 'Điều gì đã được phát hiện tại thung lũng Neandertal?',
#   'predict': 'di cốt người phi hiện đại đầu tiên từng biết đến',
#   'ground_truths': ['di cốt người phi hiện đại đầu tiên từng biết đến',
#    'di cốt người phi hiện đại đầu tiên',
#    'phát hiện di cốt người phi hiện đại đầu tiên từng biết đến',
#    'di cốt người phi hiện đại đầu tiên'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nghệ thuật tạo hình không thể tranh luận có niên đại lâu đời nhất từng phát hiện là gì?',
#   'predict': 'tượng người Sư Tử thời đại băng hà 40.000 năm tuổi',
#   'ground_truths': ['Tượng người sư tử thời đại băng hà',
#    'Tượng Venus ở Hohle Fels',
#    'Tượng người sư tử thời đại băng hà 40.000 năm tuổi',
#    'Tượng người sư tử thời đại băng hà'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Địa điểm đã tạo ra đĩa bầu trời Nebra nằm gần khu vực nào?',
#   'predict': 'thung lũng Neandertal',
#   'ground_truths': ['Nebra, Sachsen-Anhalt',
#    'Nebra, Sachsen-Anhalt',
#    'Nebra, Sachsen-Anhalt',
#    'Nebra, Sachsen-Anhalt'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Trong các loại nhạc cụ cổ nhất từng được phát hiện thì nhạc cụ cổ nhất đã có niên đại bao lâu?',
#   'predict': '42.000 năm tuổi',
#   'ground_truths': ['42.000 năm',
#    '42.000 năm tuổi',
#    '42.000 năm tuổi',
#    '42.000 năm tuổi'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Bộ lạc German đã mở rộng lãnh thổ về các hướng nam, đông và tây với vị trí xuất phát từ đâu?',
#   'predict': 'từ thế kỷ I TCN',
#   'ground_truths': ['miền nam Scandinavia và miền bắc Đức ngày nay',
#    'miền nam Scandinavia và miền bắc Đức',
#    'miền nam Scandinavia và miền bắc Đức',
#    'miền nam Scandinavia và miền bắc Đức'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Tại miền Trung và Đông Âu, khi mở rộng lãnh thổ thì bộ lạc German đã gặp phải các bộ lạc nào?',
#   'predict': 'bộ lạc Anglo-Balt, Rhur',
#   'ground_truths': ['Iran, Balt, Slav',
#    'bộ lạc Iran, Balt, Slav',
#    'Celt tại Gallia, cũng như với các bộ lạc Iran, Balt, Slav',
#    'Iran, Balt, Slav'],
#   'em_score': False,
#   'f1_score': 0.4444444444444445},
#  {'question': 'Cuộc xâm chiếm các khu vực có dân chủ yếu là người German bởi đế chế La Mã được bắt đầu khi nào?',
#   'predict': 'năm 375',
#   'ground_truths': ['thời Augustus',
#    'thời Augustus',
#    'Dưới thời Augustus',
#    'thời Augustus'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Lưu vực hai dòng sông nào đã được bộ lạc German sinh sống khi tính đến năm 100 CN?',
#   'predict': 'sông Rhine và sông Danube',
#   'ground_truths': ['sông Rhine và sông Danube',
#    'sông Rhine và sông Danube',
#    'sông Rhine và sông Danube',
#    'sông Rhine và sông Danube'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Bộ lạc Cherusker đã giành chiến thắng trước quân đoàn La Mã với sự lãnh đạo của ai?',
#   'predict': 'thủ lĩnh Sigismund',
#   'ground_truths': ['Arminius', 'Arminius', 'thủ lĩnh Arminius', 'Arminius'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Các bộ lạc nào đã phát triển mạnh mẽ tại Tây German vào thế kỷ III?',
#   'predict': 'Stananni, Frank, Saxon, Saxon, Frisii, Sicambri và Thuringii',
#   'ground_truths': ['Alemanni, Frank, Chatti, Sachsen, Frisii, Sicambri và Thuringii',
#    'Alemanni, Frank, Chatti, Sachsen, Frisii, Sicambri và Thuringii',
#    'Alemanni, Frank, Chatti, Sachsen, Frisii, Sicambri và Thuringii',
#    'Alemanni, Frank, Chatti, Sachsen, Frisii, Sicambri và Thuringii'],
#   'em_score': False,
#   'f1_score': 0.625},
#  {'question': 'Việc di chuyển về phía tây-nam của các bộ lạc German là nhờ các điều kiện nào?',
#   'predict': 'Sau cuộc xâm chiếm của người Hung vào năm 375, và La Mã suy tàn từ năm 395',
#   'ground_truths': ['cuộc xâm chiếm của người Hung vào năm 375, và La Mã suy tàn từ năm 395',
#    'cuộc xâm chiếm của người Hung vào năm 375, và La Mã suy tàn từ năm 395',
#    'Sau cuộc xâm chiếm của người Hung vào năm 375, và La Mã suy tàn từ năm 395',
#    'cuộc xâm chiếm của người Hung vào năm 375, và La Mã suy tàn từ năm 395'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vương quốc Frank được thành lập trên các vùng đất mang tên gì?',
#   'predict': 'Alsace, Alsace, và Lorraine',
#   'ground_truths': ['Austrasia, Neustria, và Aquitaine',
#    'Austrasia, Neustria, và Aquitaine',
#    'Austrasia, Neustria, và Aquitaine',
#    'Austrasia, Neustria, và Aquitaine'],
#   'em_score': False,
#   'f1_score': 0.25},
#  {'question': 'Nơi sinh sống của các bộ lạc Tây Slav thuộc khu vực nào ngày nay?',
#   'predict': 'Phần đông của Đức',
#   'ground_truths': ['phần đông của Đức',
#    'phần đông của Đức',
#    'Sorb, Veleti và liên minh Obotrit',
#    'phần đông của Đức'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Các vùng đất do La Mã thống trị đã bị xâm nhập bởi ai vào năm 260?',
#   'predict': 'các dân tộc German',
#   'ground_truths': ['các dân tộc German',
#    'dân tộc German',
#    'các dân tộc German',
#    'các dân tộc German'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Kết quả của vương quốc Karoling như thế nào khi người kế nhiệm của Frank Charlemange lên ngôi?',
#   'predict': 'không tồn tại được',
#   'ground_truths': ['phân chia',
#    'phân chia',
#    'tồn tại đến năm 843 thì bị những người thừa kế của ông phân chia',
#    'phân chia'],
#   'em_score': False,
#   'f1_score': 0.2105263157894737},
#  {'question': 'Lịch sử của đất nước nào đã gắn chặt với lịch sử Đức trong 9 thế kỷ sau khi vương triều Frank tan vỡ?',
#   'predict': 'Đế quốc La Mã thần thánh',
#   'ground_truths': ['Đế quốc La Mã',
#    'Đế quốc La Mã Thần thánh',
#    'Đế quốc La Mã Thần thánh',
#    'Đế quốc La Mã Thần thánh'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Giới hạn lãnh thổ của vùng đất Đông Frank là gì?',
#   'predict': 'Đông Frank',
#   'ground_truths': ['trải dài từ sông Rhine ở phía tây đến sông Elbe ở phía đông, và từ biển Bắc đến dãy Alpen',
#    'từ sông Rhine ở phía tây đến sông Elbe ở phía đông, và từ biển Bắc đến dãy Alpen',
#    'trải dài từ sông Rhine ở phía tây đến sông Elbe ở phía đông, và từ biển Bắc đến dãy Alpen',
#    'trải dài từ sông Rhine ở phía tây đến sông Elbe ở phía đông, và từ biển Bắc đến dãy Alpen'],
#   'em_score': False,
#   'f1_score': 0.09523809523809525},
#  {'question': 'Vào năm cuối cùng của thế kỷ 8, vương quốc nào đã được thành lập?',
#   'predict': 'vương quốc Lào',
#   'ground_truths': ['Đế quốc Karoling',
#    'Đế quốc Karoling',
#    'Đế quốc Karoling',
#    'Đế quốc Karoling'],
#   'em_score': False,
#   'f1_score': 0.3333333333333333},
#  {'question': 'Vào năm 962, người đã trở thành quốc vương của Đế quốc La Mã Thần thánh là ai?',
#   'predict': 'German/Đức',
#   'ground_truths': ['Otto I',
#    'Otto I',
#    'Quốc vương người German/Đức Otto I',
#    'Otto I'],
#   'em_score': False,
#   'f1_score': 0.2857142857142857},
#  {'question': 'Vị trí Giáo hoàng mà người Đức lần đầu tiên đảm nhiệm là vào năm nào?',
#   'predict': 'Năm 996',
#   'ground_truths': ['Năm 996', '996', 'Giáo hoàng Grêgôriô V', 'Năm 996'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vì sao mà người Đức lần đầu tiên được trở thành giáo hoàng với vị trí giáo hoàng thuộc về Grêgôriô?',
#   'predict': 'do người họ hàng của ông là Leopold III bổ nhiệm',
#   'ground_truths': ['người họ hàng của ông là Otto III bổ nhiệm',
#    'do người họ hàng của ông là Otto III bổ nhiệm',
#    'do người họ hàng của ông là Otto III bổ nhiệm- không lâu sau đăng quang Hoàng đế La Mã Thần thánh',
#    'do người họ hàng của ông là Otto III bổ nhiệm- không lâu sau đăng quang Hoàng đế La Mã Thần thánh'],
#   'em_score': False,
#   'f1_score': 0.9090909090909091},
#  {'question': 'Không lâu sau khi trở thành giáo hoàng thì Grêgôriô đã đảm nhiệm thêm chức vụ nào nữa?',
#   'predict': 'Giáo hoàng La Mã thần thánh',
#   'ground_truths': ['Hoàng đế La Mã Thần thánh',
#    'Hoàng đế La Mã Thần thánh',
#    'Hoàng đế La Mã Thần thánh',
#    'Hoàng đế La Mã Thần thánh'],
#   'em_score': False,
#   'f1_score': 0.8333333333333334},
#  {'question': 'Vì sao mà các quốc vương của La Mã thuộc gia tộc Salier lại mất đi quyền lực?',
#   'predict': 'tranh luận phong chức với Giáo hội',
#   'ground_truths': ['tranh luận phong chức với giáo hội',
#    'tranh luận phong chức với giáo hội',
#    'do tranh luận phong chức với giáo hội',
#    'tranh luận phong chức với giáo hội'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vì sao mà các vương công Đức lại khởi động cho phong trào định cư miền đông?',
#   'predict': 'nhờ mở rộng mậu dịch',
#   'ground_truths': ['gia tăng ảnh hưởng của họ về phía nam và phía đông đến các lãnh thổ mà người Slav cư trú',
#    'gia tăng ảnh hưởng của họ về phía nam và phía đông đến các lãnh thổ mà người Slav cư trú',
#    'gia tăng ảnh hưởng của họ về phía nam và phía đông đến các lãnh thổ mà người Slav cư trú',
#    'gia tăng ảnh hưởng của họ về phía nam và phía đông đến các lãnh thổ mà người Slav cư trú'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Phong trào định cư miền đông đã nổ ra vào lúc Đức được trị vì bởi ai?',
#   'predict': 'các hoàng đế thuộc gia tộc Staufer',
#   'ground_truths': ['các hoàng đế thuộc Gia tộc Staufer',
#    'Liên minh Hanse',
#    'các hoàng đế thuộc Gia tộc Staufer',
#    'các hoàng đế thuộc Gia tộc Staufer'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vì sao mà hầu hết các thành viên của Liên minh Hanse lại trở nên giàu có?',
#   'predict': 'mở rộng mậu dịch',
#   'ground_truths': ['mở rộng mậu dịch',
#    'mở rộng mậu dịch',
#    'mở rộng mậu dịch',
#    'mở rộng mậu dịch'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Việc mở rộng mậu dịch tại khu vực phía Nam được thực hiện bởi tổ chức nào?',
#   'predict': 'Liên minh Munich',
#   'ground_truths': ['Công ty Mậu dịch Đại Ravensburg',
#    'Công ty Mậu dịch Đại Ravensburg',
#    'Công ty Mậu dịch Đại Ravensburg',
#    'Công ty Mậu dịch Đại Ravensburg'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Vào giữa thập niên 50 của thế kỷ 14, sắc lệnh nào đã được ban hành bởi Hoàng đế Kari IV?',
#   'predict': 'sắc lệnh Victoria Bulle',
#   'ground_truths': ['sắc lệnh Goldene Bulle',
#    'Goldene Bulle',
#    'Goldene Bulle',
#    'Goldene Bulle'],
#   'em_score': False,
#   'f1_score': 0.75},
#  {'question': 'Sự kiện nào đã dẫn đến cho sự suy giảm dân số vào nữa đầu thế kỷ XIV?',
#   'predict': 'nạn đói lớn năm 1315',
#   'ground_truths': ['nạn đói lớn năm 1315',
#    'nạn đói lớn năm 1315',
#    'nạn đói lớn năm 1315',
#    'nạn đói lớn năm 1315'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Sau khi nạn đói 1315 thì sự kiện nào sau đó đã gây ra sự suy giảm dân số nữa đầu thế kỷ XIV?',
#   'predict': 'cái chết đen năm 134850',
#   'ground_truths': ['Cái chết Đen năm 1348–50',
#    'Cái chết Đen năm 1348–50',
#    'Cái chết Đen',
#    'Cái chết Đen năm 1348–50'],
#   'em_score': False,
#   'f1_score': 0.8000000000000002},
#  {'question': 'Các vùng đất nào đã có sự phát triển mạnh mẽ của thương nghiệp?',
#   'predict': 'các địa phương Tây Nam Bộ',
#   'ground_truths': ['Venezia, Firenze và Genova',
#    'Venezia, Firenze và Genova',
#    'Venezia, Firenze và Genova',
#    'Venezia, Firenze và Genova'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Việc truyền bá kiến thức đến đại chúng đã được đặt cơ sở bởi sự kiện nào?',
#   'predict': 'Johannes Gutenberg giới thiệu in ấn kiểu di động đến châu Âu',
#   'ground_truths': ['Johannes Gutenberg giới thiệu in ấn kiểu di động đến châu Âu',
#    'Johannes Gutenberg giới thiệu in ấn kiểu di động đến châu Âu',
#    'giới thiệu in ấn kiểu di động đến châu Âu',
#    'Johannes Gutenberg giới thiệu in ấn kiểu di động đến châu Âu'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Các nghệ sĩ nổi bật nào đã được sản sinh ra từ các trung tâm nghệ thuật và văn hóa trên lãnh thổ Đức?',
#   'predict': 'họa sĩ Hans Holbein và con trai, và Johannes Drer',
#   'ground_truths': ['họa sĩ Hans Holbein và con trai, và Albrecht Dürer',
#    'họa sĩ Hans Holbein và con trai, và Albrecht Düre',
#    'họa sĩ Hans Holbein và con trai, và Albrecht Dürer',
#    'họa sĩ Hans Holbein và con trai, và Albrecht Dürer'],
#   'em_score': False,
#   'f1_score': 0.8000000000000002},
#  {'question': 'Cuộc cải cách nào đã được bắt đầu từ việc tu sĩ Martin Luther ban hành 95 luận đề?',
#   'predict': 'cải cách Tin Lành',
#   'ground_truths': ['Cải cách Tin Lành',
#    'thách thức Giáo hội Công giáo La Mã và khởi xướng Cải cách Tin Lành',
#    'Cải cách Tin Lành',
#    'Cải cách Tin Lành'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Một nguyên tắc nào đã hình thành về đức tin của thần dân và cả vương công?',
#   'predict': 'lãnh địa của Ai thì tôn giáo theo người đó',
#   'ground_truths': ['lãnh địa của ai thì tôn giáo theo người đó',
#    'lãnh địa của ai thì tôn giáo theo người đó',
#    'lãnh địa của ai thì tôn giáo theo người đó',
#    'lãnh địa của ai thì tôn giáo theo người đó'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Đưc stin nào đã bị xem như là dị giáo?',
#   'predict': 'Đức tin Cải cách',
#   'ground_truths': ['đức tin Cải cách',
#    'đức tin Cải cách',
#    'đức tin Cải cách',
#    'đức tin Cải cách'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Một số nơi của Đức, tỉ lệ suy giảm dân số đạt cao nhất là bao nhiêu trong Chiến tranh Ba mươi Năm?',
#   'predict': '16181648',
#   'ground_truths': ['80%', '80%', '80%', '80%'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Sau năm 1648, thì các tôn giáo nào được các quân chủ Đức lựa chọn làm tôn giáo chính thức?',
#   'predict': 'Cơ Đốc giáo',
#   'ground_truths': ['Công giáo La Mã, Giáo hội Luther hay đức tin Cải cách',
#    'Công giáo La Mã, Giáo hội Luther hay đức tin Cải cách',
#    'Công giáo La Mã, Giáo hội Luther hay đức tin Cải cách',
#    'Công giáo La Mã, Giáo hội Luther hay đức tin Cải cách'],
#   'em_score': False,
#   'f1_score': 0.13333333333333333},
#  {'question': 'Số lượng lãnh thổ của Vương quốc La Mã là bao nhiêu trong thế kỉ XVIII?',
#   'predict': 'khoảng 1.800 lãnh thổ',
#   'ground_truths': ['1.800', '1.800', 'khoảng 1.800 lãnh thổ', '1.800'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vào năm bao nhiêu thì Đế quốc La Mã Thần thánh không còn được nắm quyền bởi gia tộc Habsburg?',
#   'predict': 'Năm 1806',
#   'ground_truths': ['năm 1740', '1740', 'năm 1740', 'năm 1740'],
#   'em_score': False,
#   'f1_score': 0.5},
#  {'question': 'Chồng của công chúa Maria Theresa tiếp quản vị trí Hoàng đề La Mã Thần thánh là nhờ thông qua hiệp ước nào?',
#   'predict': 'Hiệp ước Aix-La-La-France',
#   'ground_truths': ['Aix-la-Chapelle',
#    'Aix-la-Chapelle',
#    'Hiệp ước Aix-la-Chapelle',
#    'Aix-la-Chapelle'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Lịch sử Đức đã bị ảnh hưởng bởi sự đối đầu của các vương quốc nào kể từ năm 1740?',
#   'predict': 'Tây Ban Nha và Đại chiến Bắc Âu',
#   'ground_truths': ['Vương triều Habsburg Áo và Vương quốc Phổ',
#    'Vương triều Habsburg Áo và Vương quốc Phổ',
#    'Vương triều Habsburg Áo và Vương quốc Phổ',
#    'Vương triều Habsburg Áo và Vương quốc Phổ'],
#   'em_score': False,
#   'f1_score': 0.125},
#  {'question': 'Vì sao mà sau hơn 300 năm cai trị Đế quốc La Mã Thần thánh bởi gia tộc Habsburg lại bị kết thúc khi quốc vương Karl VI mất?',
#   'predict': 'Do không có Nam giới thừa kế',
#   'ground_truths': ['không có nam giới thừa kế',
#    'Do không có nam giới thừa kế',
#    'Do không có nam giới thừa kế',
#    'Do không có nam giới thừa kế'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Thời kỳ nào đã bắt đầu vào những năm Chiến tranh Cách mạng Pháp?',
#   'predict': 'thời kỳ Napoléon',
#   'ground_truths': ['Napoléon', 'Napoléon', 'thời kỳ Napoléon', 'Napoléon'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Sự kiện gì đã diễn ra ngay sau khi thời kỳ Napoléon được bắt đầu?',
#   'predict': 'Napoléon chiếm đóng Bồ Đào Nha',
#   'ground_truths': ['phiên họp cuối cùng của Quốc hội Đế quốc',
#    'phiên họp cuối cùng của Quốc hội Đế quốc',
#    'phiên họp cuối cùng của Quốc hội Đế quốc',
#    'phiên họp cuối cùng của Quốc hội Đế quốc'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Sự tan ra của Đế quốc La Mã Thần thánh là vào năm nào?',
#   'predict': 'năm 1806',
#   'ground_truths': ['Năm 1806', 'Năm 1806', 'Năm 1806', 'Năm 1806'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Trong thời chiến Napoléon, các quốc gia Đức trở thành con mồi cho các quốc gia nào đối đầu nhau để giành quyền bá chủ?',
#   'predict': 'Nga, Phổ và Vương triều Habsburg',
#   'ground_truths': ['Nga, Phổ và Vương triều Habsburg',
#    'Nga, Phổ và Vương triều Habsburg',
#    'Nga, Phổ và Vương triều Habsburg',
#    'Nga, Phổ và Vương triều Habsburg'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nước nào đã có tác động mạnh mẽ đến các quốc gia Đức, Rheinland sau khi La Mã bị tan rã?',
#   'predict': 'Pháp',
#   'ground_truths': ['Pháp', 'Pháp', 'Pháp', 'Pháp'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Thành phần tạo nên Bang liên Đức là gì?',
#   'predict': 'Đại hội Wien',
#   'ground_truths': ['hàng chục quốc gia có chủ quyền',
#    'hàng chục quốc gia có chủ quyền',
#    'hàng chục quốc gia có chủ quyền',
#    'hàng chục quốc gia có chủ quyền'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Sự cạnh tranh của các gia tộc nào bị sự phản đối của Đại hội Wien?',
#   'predict': 'Phổ và Gia tộc Habsburg cai trị Áo',
#   'ground_truths': ['Gia tộc Hohenzollern cai trị Phổ và Gia tộc Habsburg cai trị Áo',
#    'Gia tộc Hohenzollern cai trị Phổ và Gia tộc Habsburg cai trị Áo',
#    'Gia tộc Hohenzollern cai trị Phổ và Gia tộc Habsburg cai trị Áo',
#    'Gia tộc Hohenzollern cai trị Phổ và Gia tộc Habsburg cai trị Áo'],
#   'em_score': False,
#   'f1_score': 0.761904761904762},
#  {'question': 'Việc nền kinh tế của các quốc gia Đức được thống nhất là mục tiêu xúc tiến của tổ chức nào?',
#   'predict': 'Liên minh thuế quan Zollverein',
#   'ground_truths': ['Liên minh thuế quan Zollverein',
#    'Liên minh thuế quan Zollverein',
#    'Liên minh thuế quan Zollverein',
#    'Liên minh thuế quan Zollverein'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Thường dân và tri thức Đức đã tiến hành cuộc cách mạnh trong bối cảnh châu Âu như thế nào?',
#   'predict': 'một trong những quốc gia có chủ quyền lớn nhất thế giới',
#   'ground_truths': ['một loạt phong trào cách mạng diễn ra tại châu Âu, lập ra một cộng hòa tại Pháp',
#    'lập ra một cộng hòa tại Pháp',
#    'một loạt phong trào cách mạng diễn ra tại châu Âu',
#    'một loạt phong trào cách mạng diễn ra tại châu Âu'],
#   'em_score': False,
#   'f1_score': 0.10526315789473685},
#  {'question': 'Nước Đức thống nhất là mục tiêu của lễ hội nào vào tháng 5 năm 1832?',
#   'predict': 'Lễ hội Hammach',
#   'ground_truths': ['Hambach',
#    'Lễ hội Hambach',
#    'Lễ hội Hambach',
#    'Lễ hội Hambach'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Lý do nào mà chức vụ Thủ tướng Phổ đã được trao cho Otto von Bismarck vào năm 1862?',
#   'predict': 'Quốc vương Wilhelm I',
#   'ground_truths': ['Quốc vương Wilhelm I bổ nhiệm',
#    'Bismarck kết thúc thắng lợi chiến tranh với Đan Mạch',
#    'Bismarck kết thúc thắng lợi chiến tranh với Đan Mạch vào năm 1864, giúp xúc tiến lợi ích của Đức tại bán đảo Jylland',
#    'Bismarck kết thúc thắng lợi chiến tranh với Đan Mạch vào năm 1864, giúp xúc tiến lợi ích của Đức tại bán đảo Jylland'],
#   'em_score': False,
#   'f1_score': 0.8},
#  {'question': 'Sau khi Đan Mạch thua trận trước sự lãnh đạo của Bismarch vào năm 1864 đã dẫn đến hệ quả gì?',
#   'predict': 'khiến quân Pháp phải xin hàng',
#   'ground_truths': ['giúp xúc tiến lợi ích của Đức tại bán đảo Jylland',
#    'xúc tiến lợi ích của Đức tại bán đảo Jylland',
#    'giúp xúc tiến lợi ích của Đức tại bán đảo Jylland',
#    'giúp xúc tiến lợi ích của Đức tại bán đảo Jylland'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Đât nước nào đã được thành lập sau khi Bismarck giành chiến thắng trong chiến tranh với Áo?',
#   'predict': 'Áo',
#   'ground_truths': ['Bang liên Bắc Đức',
#    'Bang liên Bắc Đức',
#    'Bang liên Bắc Đức',
#    'Bang liên Bắc Đức'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Vào năm nào thì Đế quốc Đức được thành lập dưới sự đồng ý từ các vương công Đức?',
#   'predict': 'năm 1871',
#   'ground_truths': ['năm 1871', '1871', 'năm 1871', 'năm 1871'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Đế quốc Đức sau khi thành lập đã chọn thành phố nào trở thành thủ đô?',
#   'predict': 'Berlin',
#   'ground_truths': ['Berlin', 'Berlin', 'Berlin', 'Berlin'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Trong chính sách đối ngoại của Đức, Thủ tướng Bismack đã làm cách nào để đảm bảo vị thế đại quốc của Đức?',
#   'predict': 'bằng các liên minh giả mạo, cô lập pháp theo các cách thức ngoại giao, và tránh chiến tranh',
#   'ground_truths': ['các liên minh giả mạo, cô lập Pháp theo các cách thức ngoại giao, và tránh chiến tranh',
#    'các liên minh giả mạo, cô lập Pháp theo các cách thức ngoại giao, và tránh chiến tranh',
#    'bằng các liên minh giả mạo, cô lập Pháp theo các cách thức ngoại giao, và tránh chiến tranh',
#    'các liên minh giả mạo, cô lập Pháp theo các cách thức ngoại giao, và tránh chiến tranh'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Tiến trình nào đã được hầu như các cường quốc châu Âu và cả Đức dưới thời Wilhelm II thực hiện?',
#   'predict': 'tiến trình chủ nghĩa đế quốc',
#   'ground_truths': ['tiến trình chủ nghĩa đế quốc',
#    'chủ nghĩa đế quốc',
#    'chủ nghĩa đế quốc',
#    'chủ nghĩa đế quốc'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vào năm 1882, Liên minh của Đức và Áo-Hung có thêm được đất nước mới nào tham gia?',
#   'predict': 'Ý',
#   'ground_truths': ['Ý', 'Ý', 'Ý', 'Ý'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nỗi lo sợ của Liên minh Tam Cường là gì?',
#   'predict': 'người Đức, Áo và Ý trước khả năng Pháp và/ho Nga xâm nhập chống lại họ',
#   'ground_truths': ['khả năng Pháp và/hoặc Nga xâm nhập chống lại họ',
#    'Pháp và/hoặc Nga xâm nhập chống lại họ',
#    'khả năng Pháp và/hoặc Nga xâm nhập chống lại họ',
#    'khả năng Pháp và/hoặc Nga xâm nhập chống lại họ'],
#   'em_score': False,
#   'f1_score': 0.6923076923076923},
#  {'question': 'Mục đích của sự hình thành liên minh Anh, Pháp va Nga là gì?',
#   'predict': 'bảo vệ họ chống lại can thiệp của vương triều',
#   'ground_truths': ['bảo vệ họ chống lại can thiệp của Vương triều Habsburg đến các quyền lợi của Nga tại Balkan hay Đức can thiệp chống Pháp',
#    'bảo vệ họ chống lại can thiệp của Vương triều Habsburg đến các quyền lợi của Nga tại Balkan hay Đức can thiệp chống Pháp',
#    'bảo vệ họ chống lại can thiệp của Vương triều Habsburg đến các quyền lợi của Nga tại Balkan hay Đức can thiệp chống Pháp',
#    'bảo vệ họ chống lại can thiệp của Vương triều Habsburg đến các quyền lợi của Nga tại Balkan hay Đức can thiệp chống Pháp'],
#   'em_score': False,
#   'f1_score': 0.5714285714285715},
#  {'question': 'Những sự kiện nào đã diễn ra sau khi thái tử Áo bị ám sát vào ngày 28 tháng 6 năm 1914?',
#   'predict': 'Đế quốc Áo-Hung tấn công Normandy và kích hoạt Chiến tranh thế giới thứ nhất',
#   'ground_truths': ['Đế quốc Áo-Hung tấn công Serbia và kích hoạt Chiến tranh thế giới thứ nhất',
#    'Đế quốc Áo-Hung tấn công Serbia và kích hoạt Chiến tranh thế giới thứ nhất',
#    'Đế quốc Áo-Hung tấn công Serbia và kích hoạt Chiến tranh thế giới thứ nhất',
#    'Đế quốc Áo-Hung tấn công Serbia và kích hoạt Chiến tranh thế giới thứ nhất'],
#   'em_score': False,
#   'f1_score': 0.9333333333333333},
#  {'question': 'Vào ngày nào thì thỏa thuận đình chiến tổng thể để kết thúc chiến tranh có hiệu lực?',
#   'predict': 'ngày 11 tháng 11',
#   'ground_truths': ['ngày 11 tháng 11',
#    'ngày 11 tháng 11',
#    'ngày 11 tháng 11',
#    'ngày 11 tháng 11'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Sự thiệt hại về thuộc địa của Đức sau khi bại trận trong Chiến tranh thế giới thứ nhất là gì?',
#   'predict': 'mất khoảng 30% lãnh thổ của họ tại châu Âu (các khu vực lân cận)',
#   'ground_truths': ['mất khoảng 30% lãnh thổ của họ tại châu Âu (các khu vực này có cư dân chủ yếu là người thuộc dân tộc Ba Lan, Pháp và Đan Mạch), và toàn bộ thuộc địa tại châu Phi và Thái Bình Dương',
#    'mất khoảng 30% lãnh thổ của họ tại châu Âu (các khu vực này có cư dân chủ yếu là người thuộc dân tộc Ba Lan, Pháp và Đan Mạch), và toàn bộ thuộc địa tại châu Phi và Thái Bình Dương',
#    'có khoảng hai triệu binh sĩ Đức bị giết',
#    'mất khoảng 30% lãnh thổ của họ tại châu Âu (các khu vực này có cư dân chủ yếu là người thuộc dân tộc Ba Lan, Pháp và Đan Mạch), và toàn bộ thuộc địa tại châu Phi và Thái Bình Dương'],
#   'em_score': False,
#   'f1_score': 0.45614035087719296},
#  {'question': 'Hiệp định Versailles đã bị người Đức xem là gì?',
#   'predict': 'điều sỉ nhục và bất công',
#   'ground_truths': ['là điều sỉ nhục và bất công',
#    'điều sỉ nhục và bất công',
#    'là điều sỉ nhục và bất công',
#    'là điều sỉ nhục và bất công'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Theo như các nhà sử gia sau này thì hiệp định Versailles đã ảnh hưởng đến điều gì?',
#   'predict': 'Adolf Hitler vươn lên',
#   'ground_truths': ['việc Adolf Hitler vươn lên',
#    'Adolf Hitler vươn lên',
#    'ảnh hưởng đến việc Adolf Hitler vươn lên',
#    'Adolf Hitler vươn lên'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vào cuối năm 1918, Đức được quyết định trở thành nước có thể chế chính trị nào?',
#   'predict': 'dân chủ',
#   'ground_truths': ['cộng hòa',
#    'nước cộng hòa',
#    'nước cộng hòa',
#    'nước cộng hòa'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Cuộc khủng hoảng nền kinh tế toàn cầu xâm nhập vào Đức vào năm nào?',
#   'predict': 'năm 2008',
#   'ground_truths': ['năm 1929', '1929', 'năm 1929', 'năm 1929'],
#   'em_score': False,
#   'f1_score': 0.5},
#  {'question': 'Quyền lực nào mà chính phủ của Heinrich Bruning được trao bởi tổng thống vào năm 1930?',
#   'predict': 'quyền lực tượng trưng',
#   'ground_truths': ['quyền hành động mà không cần nghị viện phê chuẩn',
#    'quyền hành động mà không cần nghị viện phê chuẩn',
#    'quyền hành động mà không cần nghị viện phê chuẩn',
#    'quyền hành động mà không cần nghị viện phê chuẩn'],
#   'em_score': False,
#   'f1_score': 0.14285714285714288},
#  {'question': 'Hâu quả nào dành cho Đức sau khi các đường phố nhuộm đầy máu của các cuộc giao tranh?',
#   'predict': 'một kế hoạch tái cơ cấu nợ và tạo một tiền tệ mới vào năm 1924 mở ra thập niên 2000',
#   'ground_truths': ['binh sĩ Bỉ và Pháp chiếm đóng Ruhr và lạm phát gia tăng với đỉnh điểm là lạm phát phi mã năm 1922-1923',
#    'binh sĩ Bỉ và Pháp chiếm đóng Ruhr và lạm phát gia tăng với đỉnh điểm là lạm phát phi mã năm 1922-1923',
#    'tỷ lệ thất nghiệp cao đến gần 32% vào năm 1932',
#    'binh sĩ Bỉ và Pháp chiếm đóng Ruhr và lạm phát gia tăng với đỉnh điểm là lạm phát phi mã năm 1922-1923'],
#   'em_score': False,
#   'f1_score': 0.125},
#  {'question': 'Giai đoạn 5 năm kể từ năm 1924 được các nhà nghiên cứu lịch sử miêu tả là gì?',
#   'predict': 'mô hình thống kê từ nhà vật lý người Ấn Độ Vijay Nath Bose',
#   'ground_truths': ['là "ổn định cục bộ"',
#    'ổn định cục bộ',
#    '"ổn định cục bộ"',
#    'là "ổn định cục bộ"'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Vào năm 1932, cuộc bầu cử Liên bang đã có chiến thắng thuộc về đảng nào?',
#   'predict': 'Dân chủ',
#   'ground_truths': ['Đảng Quốc xã',
#    'Đảng Quốc xã',
#    'Đảng Quốc xã',
#    'Đảng Quốc xã'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Hindenburg đã có quyết định gì sau hàng loạt thất bại của các nội các?',
#   'predict': 'bổ nhiệm Hitler làm thủ tướng của Đức vào năm 1933',
#   'ground_truths': ['bổ nhiệm Hitler làm thủ tướng',
#    'bổ nhiệm Hitler làm thủ tướng của Đức vào năm 1933',
#    'bổ nhiệm Hitler làm thủ tướng của Đức vào năm 1933',
#    'bổ nhiệm Hitler làm thủ tướng của Đức vào năm 1933'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Các dân quyền đã bị vô hiệu hóa sau khi sự kiện gì diễn ra?',
#   'predict': 'cuộc kháng nghị dân quyền đại chúng',
#   'ground_truths': ['vụ hỏa hoạn tại Tòa nhà Quốc hội',
#    'vụ hỏa hoạn tại Tòa nhà Quốc hội',
#    'vụ hỏa hoạn tại Tòa nhà Quốc hội',
#    'vụ hỏa hoạn tại Tòa nhà Quốc hội'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Vào năm nào thì Tòa nhà Quốc hội đã bị cháy?',
#   'predict': 'năm 1933',
#   'ground_truths': ['năm 1933', '1933', 'năm 1933', 'năm 1933'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Hitler đã có được quyền gì khi vào năm 1933 Đạo luật Cho quyền có hiệu lực?',
#   'predict': 'lập pháp không bị hạn chế',
#   'ground_truths': ['quyền lực lập pháp không bị hạn chế',
#    'lập pháp không bị hạn chế',
#    'quyền lực lập pháp không bị hạn chế',
#    'quyền lực lập pháp không bị hạn chế'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Với cái tên autobahn, dự án công trình công cộng nổi tiếng nhất còn có tên khác là gì?',
#   'predict': 'Đường bộ cao tốc',
#   'ground_truths': ['đường bộ cao tốc',
#    'đường bộ cao tốc',
#    'đường bộ cao tốc',
#    'đường bộ cao tốc'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Trong lĩnh vực vận chuyển, dự án công cộng nổi bật nhất có tên gọi là gì?',
#   'predict': 'Autobahn',
#   'ground_truths': ['Ga Zwickau Hauptbahnhof',
#    'Ga Zwickau Hauptbahnhof',
#    'Ga Zwickau Hauptbahnhof',
#    'Ga Zwickau Hauptbahnhof'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Trong vòng 5 năm kể từ năm 1934, tình hình lao động ở Đức như thế nào?',
#   'predict': 'tỷ lệ thất nghiệp giảm mạnh và lương trung bình theo giờ và theo tuần đều tăng lên',
#   'ground_truths': ['tỷ lệ thất nghiệp giảm mạnh và lương trung bình theo giờ và theo tuần đều tăng lên',
#    'tỷ lệ thất nghiệp giảm mạnh và lương trung bình theo giờ và theo tuần đều tăng lên',
#    'tỷ lệ thất nghiệp giảm mạnh',
#    'tỷ lệ thất nghiệp giảm mạnh và lương trung bình theo giờ và theo tuần đều tăng lên'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Bao nhiêu người Đức đã có việc làm sau khi các công trình công cộng được thực hiện vào năm 1934?',
#   'predict': '1,7 triệu người',
#   'ground_truths': ['1,7 triệu người',
#    '1,7 triệu',
#    '1,7 triệu người Đức',
#    '1,7 triệu người'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Trong các dự án của năm 1934, công trình xây dựng nào nổi bật trong lĩnh vực thủy điện?',
#   'predict': 'đập Rur',
#   'ground_truths': ['Đập Rur', 'Đập Rur', 'Đập Rur', 'Đập Rur'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vấn đề nào đã được nêu ra trong Hiệp ước Molotov-Ribbentrop vào năm 1939?',
#   'predict': 'phân chia Đông Âu thành các khu vực ảnh hưởng của Đức và Liên Xô',
#   'ground_truths': ['phân chia Đông Âu thành các khu vực ảnh hưởng của Đức và Liên Xô',
#    'phân chia Đông Âu thành các khu vực ảnh hưởng của Đức và Liên Xô',
#    'phân chia Đông Âu thành các khu vực ảnh hưởng của Đức và Liên Xô',
#    'phân chia Đông Âu thành các khu vực ảnh hưởng của Đức và Liên Xô'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Thế chiến thứ hai được khởi động thông qua sự kiện nào?',
#   'predict': 'Chiến tranh Lạnh',
#   'ground_truths': ['Đức xâm chiếm Ba Lan',
#    'ngày 1 tháng 9 năm 1939 Đức xâm chiếm Ba Lan',
#    'Đức xâm chiếm Ba Lan',
#    'Đức xâm chiếm Ba Lan'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Hai nước Pháp và Anh đã có phản ứng như thế nào trước sự xâm lược Ba Lan của Đức?',
#   'predict': 'phản ứng trước hành động của Hitler, Anh và Pháp tuyên chiến với Đức',
#   'ground_truths': ['tuyên chiến với Đức',
#    'tuyên chiến với Đức',
#    'tuyên chiến với Đức',
#    'tuyên chiến với Đức'],
#   'em_score': False,
#   'f1_score': 0.4444444444444445},
#  {'question': 'Các nước nào đã bị Đức đánh bại và chiếm đóng trong năm 1941?',
#   'predict': 'Liên Xô và Liên Xô',
#   'ground_truths': ['Nam Tư, Hy Lạp và Liên Xô',
#    'Đan Mạch và Na Uy, Hà Lan, Bỉ, Luxembourg, và Pháp',
#    'Nam Tư, Hy Lạp và Liên Xô',
#    'Nam Tư, Hy Lạp và Liên Xô'],
#   'em_score': False,
#   'f1_score': 0.5},
#  {'question': 'Từ sau sự kiện nào thì sự thất bại liên tiếp thuộc về Đức?',
#   'predict': 'Chiến tranh Lạnh',
#   'ground_truths': ['chiến thắng của Liên Xô trong Trận Stalingrad',
#    'chiến thắng của Liên Xô trong Trận Stalingrad',
#    'chiến thắng của Liên Xô trong Trận Stalingrad',
#    'chiến thắng của Liên Xô trong Trận Stalingrad'],
#   'em_score': False,
#   'f1_score': 0.18181818181818182},
#  {'question': 'Số lượng người Do Thái trong tổng số 10 triệu người đã bị Đức hành quyết một cách hệ thống là bao nhiêu?',
#   'predict': 'sáu triệu người',
#   'ground_truths': ['sáu triệu người',
#    'sáu triệu',
#    'sáu triệu người Do Thái',
#    'sáu triệu người Do Thái'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Trong tổng số 10 triệu người bị Đức giết chết thì hơn một nữa là người nào?',
#   'predict': 'người Do Thái',
#   'ground_truths': ['người Do Thái',
#    'Do Thái',
#    'người Do Thái',
#    'người Do Thái'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nơi nào là nơi đã tổ chức phiên tòa luận tội các thành viên của Quốc xã?',
#   'predict': 'Tòa án Dân biểu',
#   'ground_truths': ['Tòa án Nürnberg',
#    'các quốc gia bị Đức chiếm đóng',
#    'Tòa án Nürnberg',
#    'Tòa án Nürnberg'],
#   'em_score': False,
#   'f1_score': 0.5714285714285715},
#  {'question': 'Số lượng người Ukraina đã bị Đức giết chết bởi quy định của Quốc xã là bao nhiêu?',
#   'predict': '2,7 triệu người',
#   'ground_truths': ['1,3 triệu người',
#    '2,7 triệu người Ba Lan, 1,3 triệu người Ukraina, và ước tính lên đến 2,8 triệu tù binh Liên Xô',
#    '1,3 triệu người',
#    '1,3 triệu người'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Tại Đông Âu đã có bao nhiêu người bị trục xuất là người dân tộc Đức?',
#   'predict': 'Khoảng 12 triệu người',
#   'ground_truths': ['Khoảng 12 triệu người',
#    'Khoảng 12 triệu người',
#    'Khoảng 12 triệu người',
#    'Khoảng 12 triệu người'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Lãnh thổ của Đức và cả Berlin đã bị chia ra thành bao nhiêu khu vực sau khi Đức bại trận?',
#   'predict': 'bốn',
#   'ground_truths': ['bốn khu vực',
#    'bốn khu vực',
#    'bốn khu vực',
#    'bốn khu vực'],
#   'em_score': False,
#   'f1_score': 0.5},
#  {'question': 'Cộng hòa Liên bang Đức được thành lập vào thời gian nào?',
#   'predict': 'ngày 7 tháng 10 năm 1949',
#   'ground_truths': ['ngày 23 tháng 5 năm 1949',
#    'ngày 23 tháng 5 năm 1949',
#    'ngày 23 tháng 5 năm 1949',
#    'ngày 23 tháng 5 năm 1949'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Theo tiếng anh thì Cộng hòa Dân chủ Đức có tên là gì?',
#   'predict': 'Cộng hòa Dân chủ Đức',
#   'ground_truths': ['Deutsche Demokratische Republik',
#    'Deutsche Demokratische Republik',
#    'Deutsche Demokratische Republik',
#    'Deutsche Demokratische Republik'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Mục đích khi cả Đông Đức và Tây Đức đều chọn các thủ đô lâm thời là gì?',
#   'predict': 'nhằm nhấn mạnh lập trường của mình rằng giải pháp hai nhà nước là một tình trạng nhân tạo và tạm thời',
#   'ground_truths': ['nhấn mạnh lập trường của mình rằng giải pháp hai nhà nước là một tình trạng nhân tạo và tạm thời',
#    'nhấn mạnh lập trường của mình rằng giải pháp hai nhà nước là một tình trạng nhân tạo và tạm thời',
#    'nhằm nhấn mạnh lập trường của mình rằng giải pháp hai nhà nước là một tình trạng nhân tạo và tạm thời',
#    'nhấn mạnh lập trường của mình rằng giải pháp hai nhà nước là một tình trạng nhân tạo và tạm thời'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Đông Đức được hình thành trên khu vực do nước nào đóng quân?',
#   'predict': 'Liên Xô',
#   'ground_truths': ['Liên Xô', 'Liên Xô', 'Đông Berlin', 'Liên Xô'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Kế hoạch Marshall bắt đầu chi viện cho Tây Đức vào năm nào?',
#   'predict': 'năm 1948',
#   'ground_truths': ['năm 1948', '1948', 'năm 1948', 'năm 1948'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Ngành nào đã được Đức tiến hành khôi phục và phát triển dựa trên viện trợ của kế hoạch Marshall?',
#   'predict': 'ngành công nghiệp',
#   'ground_truths': ['ngành công nghiệp',
#    'ngành công nghiệp',
#    'ngành công nghiệp',
#    'ngành công nghiệp'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vào năm nào thì chức vụ thủ tướng liên bang không còn thuộc về Konrad Adenauer?',
#   'predict': 'năm 1963',
#   'ground_truths': ['năm 1963', '1963', 'năm 1963', 'năm 1963'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Tổ chức nào đã được thành lập bởi Tây Đức và các nước châu Âu vào năm 1957?',
#   'predict': 'Cộng đồng Kinh tế châu Âu',
#   'ground_truths': ['Cộng đồng Kinh tế châu Âu',
#    'Cộng đồng Kinh tế châu Âu',
#    'Cộng đồng Kinh tế châu Âu',
#    'Cộng đồng Kinh tế châu Âu'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Giai đoạn phát triển kinh tế một cách dài lâu của Tây Đức được bắt đầu vào khoảng thời gian nào?',
#   'predict': 'Thời Tây Hán',
#   'ground_truths': ['đầu thập niên 1950',
#    'đầu thập niên 1950',
#    'thập niên 1950',
#    'đầu thập niên 1950'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Nhờ vào lực lượng nào mà Liên Xô có thể quản lí được về quân sự và chính trị của Đông Đức?',
#   'predict': 'lực lượng chiếm đóng và Khối Warszawa',
#   'ground_truths': ['lực lượng chiếm đóng và Khối Warszawa',
#    'lực lượng chiếm đóng và Khối Warszawa',
#    'lực lượng chiếm đóng và Khối Warszawa',
#    'lực lượng chiếm đóng và Khối Warszawa'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Tây Đức dưới cái nhìn của phần lớn dân Đông Đức là như thế nào?',
#   'predict': 'bằng khoảng 1/4 so với Tây Đức',
#   'ground_truths': ['tự do và thịnh vượng',
#    'đại diện cho tự do và thịnh vượn',
#    'đại diện cho tự do và thịnh vượng',
#    'tự do và thịnh vượng'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Vì sao mà bức tường Berlin lại được dựng lên năm 1961?',
#   'predict': 'khoảng một phần tư người Đông Đức đã rời bò đất nước trước khi bức tường Berlin được xây dựng',
#   'ground_truths': ['ngăn người Đông Đức đào thoát sang Tây Đức',
#    'ngăn người Đông Đức đào thoát sang Tây Đức',
#    'ngăn người Đông Đức đào thoát sang Tây Đức',
#    'ngăn người Đông Đức đào thoát sang Tây Đức'],
#   'em_score': False,
#   'f1_score': 0.20689655172413793},
#  {'question': 'Vào năm nào thì một biểu tượng của chiến tranh lạnh tại Berlin bị sụp đổ?',
#   'predict': 'năm 1989',
#   'ground_truths': ['năm 1989', '1989', 'năm 1989', 'năm 1989'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Tổ chức kinh tế nào Đông Đức là một thành viên trong đó?',
#   'predict': 'Hội đồng Tương trợ Kinh tế',
#   'ground_truths': ['Hội đồng Tương trợ Kinh tế SEV',
#    'Hội đồng Tương trợ Kinh tế SEV',
#    'Hội đồng Tương trợ Kinh tế SEV',
#    'Hội đồng Tương trợ Kinh tế SEV'],
#   'em_score': False,
#   'f1_score': 0.923076923076923},
#  {'question': 'Vào năm nào thì đã xuất sự suy giảm mối căng thẳng giữa Đông và Tây Đức?',
#   'predict': 'đầu thập niên 1970',
#   'ground_truths': ['đầu thập niên 1970',
#    'đầu thập niên 1970',
#    'thập niên 1970',
#    'đầu thập niên 1970'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Thông qua nước nào mà người dân Đông Đức có thể di cư sang Tây Đức vào năm 1989?',
#   'predict': 'Hungary',
#   'ground_truths': ['Hungary',
#    'Hungary',
#    'phá Bức màn sắt và mở cửa biên giới',
#    'Hungary'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Mục đích ban đầu của việc Đông Đức cho phép người dân có thể sang Tây Đức là gì?',
#   'predict': 'duy trì Đông Đức',
#   'ground_truths': ['giúp duy trì Đông Đức',
#    'giúp duy trì Đông Đức',
#    'nhằm giúp duy trì Đông Đức',
#    'giúp duy trì Đông Đức'],
#   'em_score': False,
#   'f1_score': 0.888888888888889},
#  {'question': 'Vào ngày nào thì Tây Đức và Đông Đức chính thức thống nhất?',
#   'predict': 'Ngày 23 tháng 5 năm 1990',
#   'ground_truths': ['ngày 3 tháng 10 năm 1990',
#    'ngày 3 tháng 10 năm 1990',
#    'ngày 3 tháng 10 năm 1990',
#    'ngày 3 tháng 10 năm 1990'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Số lượng bang của Đông Đức cũ được sát nhập vào Cộng hòa Liên bang Đức sau khi thông nhất là bao nhiêu?',
#   'predict': 'năm bang',
#   'ground_truths': ['năm bang', 'năm', 'bốn', 'bốn'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Sự thật của việc thống nhất nước Đức là gì?',
#   'predict': 'sự mở rộng thêm Cộng hòa Liên bang Đức và không phải là một quốc gia kế thừa',
#   'ground_truths': ['là sự mở rộng thêm Cộng hòa Liên bang Đức',
#    'sự mở rộng thêm Cộng hòa Liên bang Đức và không phải là một quốc gia kế thừa',
#    'sự mở rộng thêm Cộng hòa Liên bang Đức và không phải là một quốc gia kế thừa',
#    'sự mở rộng thêm Cộng hòa Liên bang Đức và không phải là một quốc gia kế thừa'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Nước Đức đã làm gì khi việc thống nhất Đức thực chất chỉ là sự lớn mạnh của Tây Đức?',
#   'predict': 'mở rộng thêm Cộng hòa Liên bang Đức và không phải là một quốc gia kế thừa',
#   'ground_truths': ['họ duy trì toàn bộ tư cách thành viên của Tây Đức trong các tổ chức quốc tế',
#    'duy trì toàn bộ tư cách thành viên của Tây Đức trong các tổ chức quốc tế',
#    'duy trì toàn bộ tư cách thành viên của Tây Đức trong các tổ chức quốc tế',
#    'duy trì toàn bộ tư cách thành viên của Tây Đức trong các tổ chức quốc tế'],
#   'em_score': False,
#   'f1_score': 0.11764705882352941},
#  {'question': 'Tại nước Đức thống nhất, việc Berlin trở thành thủ đô là do dựa vào điều gì?',
#   'predict': 'Đạo luật Berlin/Bonn được thông qua vào năm 1994',
#   'ground_truths': ['Dựa theo Đạo luật Berlin/Bonn',
#    'Đạo luật Berlin/Bonn được thông qua vào năm 1994',
#    'Dựa theo Đạo luật Berlin/Bonn được thông qua vào năm 1994',
#    'Đạo luật Berlin/Bonn được thông qua vào năm 1994'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Vào năm nào thì chính phủ hoàn toàn được chuyển sang Berlin?',
#   'predict': 'năm 1989',
#   'ground_truths': ['năm 1999', '1999', 'năm 1994', 'năm 1994'],
#   'em_score': False,
#   'f1_score': 0.5},
#  {'question': 'Ai là người đã thắng cử chức vụ thủ tướng trong cuộc bầu cử vào năm 1998?',
#   'predict': 'Mahmoud Ahmadinejad',
#   'ground_truths': ['Gerhard Schröder',
#    'Gerhard Schröder',
#    'chính trị gia Gerhard Schröder của SPD',
#    'Gerhard Schröder'],
#   'em_score': False,
#   'f1_score': 0},
#  {'question': 'Hiệp ước nào đã được Đức đồng ý vào năm 1992?',
#   'predict': 'Hiệp ước Maastricht',
#   'ground_truths': ['Hiệp ước Maastricht',
#    'Hiệp ước Maastricht',
#    'Hiệp ước Maastricht',
#    'Hiệp ước Maastricht'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Khu vực sử dụng đồng tiền chung euro đã được Đức và các nước châu Âu thành lập vào năm nào?',
#   'predict': 'năm 1999',
#   'ground_truths': ['năm 1999', '1999', 'năm 1999', 'năm 1999'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Năm 2007, Hiệp ước nào đã được Đức ký kết?',
#   'predict': 'Hiệp ước Maastricht',
#   'ground_truths': ['Hiệp ước Lisbon',
#    'Lisbon',
#    'Hiệp ước Lisbon',
#    'Hiệp ước Lisbon'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Mục đích của của NATO là gì thông qua việc Đức phái một lực lượng binh sĩ đến Afghanistan?',
#   'predict': 'cung cấp an ninh tại đó sau khi Taliban bị lật đổ',
#   'ground_truths': ['cung cấp an ninh tại đó sau khi Taliban bị lật đổ',
# ...
#    'thành ngoại quách và Cung thành của Trường An đã bị Chu Ôn phá hủy triệt để, đóng ba cổng thành của Hoàng thành, chỉ để lại Huyền Vũ môn ở phía bắc',
#    'thành ngoại quách và Cung thành của Trường An đã bị Chu Ôn phá hủy triệt để, đóng ba cổng thành của Hoàng thành, chỉ để lại Huyền Vũ môn ở phía bắc'],
#   'em_score': False,
#   'f1_score': 0.8363636363636363},
#  {'question': 'Thời nhà Minh, triều đình đã làm những gì đối với thành Tây An?',
#   'predict': 'tiến hành xây dựng thành Tây An với quy mô lớn',
#   'ground_truths': ['triều đình tiến hành xây dựng thành Tây An với quy mô lớn',
#    'tiến hành xây dựng thành Tây An với quy mô lớn',
#    'tiến hành xây dựng thành Tây An với quy mô lớn',
#    'tiến hành xây dựng thành Tây An với quy mô lớn'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Ai đã chủ trì việc mở rộn thành Tây An trong giai đoạn 1374-1378?',
#   'predict': 'Đô đốc Bộc Anh',
#   'ground_truths': ['đô đốc Bộc Anh (濮英)',
#    'đô đốc Bộc Anh',
#    'đô đốc Bộc Anh',
#    'đô đốc Bộc Anh'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Tường thành của Tây An đã được bảo dưỡng như thế nào?',
#   'predict': 'gia cố trên cơ sở tường thành của Hoàng Thành từ thời Đường, xây mới tường thành hai mặt đông và bắc',
#   'ground_truths': ['Tường thành hai mặt tây và nam được gia cố trên cơ sở tường thành của hoàng thành từ thời Đường, xây mới tường thành hai mặt đông và bắc',
#    'gia cố trên cơ sở tường thành của hoàng thành từ thời Đường, xây mới tường thành hai mặt đông và bắc',
#    'Tường thành hai mặt tây và nam được gia cố trên cơ sở tường thành của hoàng thành từ thời Đường, xây mới tường thành hai mặt đông và bắc',
#    'Tường thành hai mặt tây và nam được gia cố trên cơ sở tường thành của hoàng thành từ thời Đường, xây mới tường thành hai mặt đông và bắc'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Thành Tây An sau khi mở rộng đã có gì nổi bật hơn so với thành Tây An?',
#   'predict': 'thành Tây An vì thế dài và rộng hơn',
#   'ground_truths': ['thành Tây An vì thế dài và rộng hơn so với Phụng Nguyên lộ thành của triều Nguyên',
#    'dài và rộng hơn',
#    'dài và rộng hơn',
#    'dài và rộng hơn'],
#   'em_score': False,
#   'f1_score': 0.6666666666666666},
#  {'question': 'Vào cuối thời Minh, nước này đã trải qua những khó khăn gì?',
#   'predict': 'Hà Nam cũng trở thành khu vực phải hứng chịu sự phá hoại nghiêm trọng từ chiến tranh, dân số suy giảm',
#   'ground_truths': ['triều đình trở nên hủ bại, đất nước mất mùa đói kém, người dân nhiều nơi nổi loạn, trong đó có Thiểm Tây',
#    'trở nên hủ bại, đất nước mất mùa đói kém, người dân nhiều nơi nổi loạn',
#    'triều đình trở nên hủ bại, đất nước mất mùa đói kém, người dân nhiều nơi nổi loạn',
#    'thất bại trước liên quân giữa quân Thanh và quân Ngô Tam Quế'],
#   'em_score': False,
#   'f1_score': 0.09523809523809523},
#  {'question': 'Những đơn vị hành chính của thời nhà Thanh đã có những thay đổi như thế nào so với nhà Minh?',
#   'predict': 'thay đổi về hành chính, kinh tế, quân sự và đã chuyển kinh đô từ Thăng Long về Thanh Hóa',
#   'ground_truths': ['triều đình phế bỏ xưng hiệu "bố chính sứ ti" của triều Minh, đổi sang gọi là hành tỉnh hoặc gọi tắt là tỉnh',
#    'phế bỏ xưng hiệu "bố chính sứ ti" của triều Minh, đổi sang gọi là hành tỉnh hoặc gọi tắt là tỉnh',
#    'phế bỏ xưng hiệu "bố chính sứ ti" của triều Minh, đổi sang gọi là hành tỉnh hoặc gọi tắt là tỉnh',
#    'phế bỏ xưng hiệu "bố chính sứ ti" của triều Minh, đổi sang gọi là hành tỉnh hoặc gọi tắt là tỉnh'],
#   'em_score': False,
#   'f1_score': 0.14285714285714282},
#  {'question': 'Những khu vực nào ngày nay thuộc Thiểm Tây hành tỉnh vào những năm đầu thời Thanh?',
#   'predict': 'các vùng phía đông của Cam Túc, Ninh Hạ và Thanh Hải',
#   'ground_truths': ['toàn bộ Thiểm Tây ngày nay, cộng thêm các vùng phía đông của Cam Túc, Ninh Hạ và Thanh Hải ngày nay',
#    'Cam Túc, Ninh Hạ và Thanh Hải',
#    'toàn bộ Thiểm Tây ngày nay, cộng thêm các vùng phía đông của Cam Túc, Ninh Hạ và Thanh Hải ngày nay',
#    'toàn bộ Thiểm Tây ngày nay, cộng thêm các vùng phía đông của Cam Túc, Ninh Hạ và Thanh Hải ngày nay'],
#   'em_score': False,
#   'f1_score': 0.7368421052631579},
#  {'question': 'Tả bố chính sử ti vẫn trú tại Tây An quản lý những vùng nào?',
#   'predict': 'bốn phủ Tây An, Diên An, Diên An, Phượng Tường, Hán Trung cùng Hưng An Châu',
#   'ground_truths': ['quản lý bốn phủ Tây An, Diên An, Phượng Tường, Hán Trung cùng Hưng An châu',
#    'Tây An, Diên An, Phượng Tường, Hán Trung cùng Hưng An châu',
#    'Tây An, Diên An, Phượng Tường, Hán Trung cùng Hưng An châu',
#    'Tây An, Diên An, Phượng Tường, Hán Trung cùng Hưng An châu'],
#   'em_score': False,
#   'f1_score': 0.8799999999999999},
#  {'question': 'Tây An giữ vai trò gì trong suốt triều đại nhà Thanh?',
#   'predict': 'thủ phủ của Thiểm Tây',
#   'ground_truths': ['Tây An là thủ phủ của Thiểm Tây',
#    'thủ phủ của Thiểm Tây',
#    'thủ phủ của Thiểm Tây',
#    'thủ phủ của Thiểm Tây'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Năm 1649, triều Thanh đã có những việc làm gì đối với đông bắc bộ thành Tây An?',
#   'predict': 'lấy đông bắc bộ thành Tây An thời Minh để hình thành một thành phòng thủ, gọi là Mãn Thành',
#   'ground_truths': ['triều Thanh lấy đông bắc bộ thành Tây An thời Minh để hình thành một thành phòng thủ, gọi là Mãn thành',
#    'hình thành một thành phòng thủ, gọi là Mãn thành',
#    'để hình thành một thành phòng thủ, gọi là Mãn thành',
#    'để hình thành một thành phòng thủ, gọi là Mãn thành'],
#   'em_score': False,
#   'f1_score': 0.9500000000000001},
#  {'question': 'Những người Hán ở Thiểm Tây vào thời Thanh đã có những quyết định gì?',
#   'predict': 'di cư đến Tân Cương',
#   'ground_truths': ['Nhiều người Hán đã từ Thiểm Tây di cư đến Tân Cương',
#    'di cư đến Tân Cương',
#    'di cư đến Tân Cương',
#    'di cư đến Tân Cương'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Những người Hán được xếp vào những tầng lớp nào vào thời Thanh?',
#   'predict': 'thương nhân nếu không mang thân phận nô lệ',
#   'ground_truths': ['Họ được phân loại là thương nhân nếu không mang thân phận nô lệ',
#    'thương nhân nếu không mang thân phận nô lệ',
#    'thương nhân nếu không mang thân phận nô lệ',
#    'thương nhân nếu không mang thân phận nô lệ'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Với lợi thế là còn nhiều đất trống, Thiểm Nam đã có những sức hút gì đối với những người nhập cư trong những năm 1770?',
#   'predict': 'thu hút người nhập cư trên quy mô lớn sau khi Hồ Bắc và Tứ Xuyên xảy ra nạn đói nghiêm trọng và mùa màng thất bát',
#   'ground_truths': ['vùng đã thu hút người nhập cư trên quy mô lớn sau khi Hồ Bắc và Tứ Xuyên xảy ra nạn đói nghiêm trọng và mùa màng thất bát trong thập niên 1770',
#    'sau khi Hồ Bắc và Tứ Xuyên xảy ra nạn đói nghiêm trọng và mùa màng thất bát',
#    'sau khi Hồ Bắc và Tứ Xuyên xảy ra nạn đói nghiêm trọng và mùa màng thất bát',
#    'sau khi Hồ Bắc và Tứ Xuyên xảy ra nạn đói nghiêm trọng và mùa màng thất bát'],
#   'em_score': False,
#   'f1_score': 0.9},
#  {'question': 'Ở Thiểm Nam những năm đầu thế kỷ XIX, tỉ lệ người nhập cư đến từ Trung và Nam Trung Quốc chiếm bao nhiêu?',
#   'predict': '90%',
#   'ground_truths': ['đã chiếm đến 90% tại một số nơi ở Thiểm Nam',
#    '90%',
#    '90%',
#    '90%'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Trong khoảng giai đoạn 1796-1804, những mối bất hòa giữa triều đình với những phần tử chống đối đã gây ra điều gì?',
#   'predict': 'tiến hành khởi nghĩa Bạch Liên giáo ở vùng giáp ranh giữa Tứ Xuyên-Thiểm Tây-Hiểm Tây-Hiểm Tây-Hiểm Tây-Hiểm Tây-Hiểm Tây-Hiểm Tây-Hiểm Tây-Hiểm',
#   'ground_truths': ['những người bất mãn với triều đình đã tiến hành Khởi nghĩa Bạch Liên giáo ở vùng giáp ranh giữa Tứ Xuyên-Thiểm Tây-Hồ Bắc-Hà Nam',
#    'tiến hành Khởi nghĩa Bạch Liên giáo ở vùng giáp ranh giữa Tứ Xuyên-Thiểm Tây-Hồ Bắc-Hà Nam',
#    'tiến hành Khởi nghĩa Bạch Liên giáo ở vùng giáp ranh giữa Tứ Xuyên-Thiểm Tây-Hồ Bắc-Hà Nam',
#    'tiến hành Khởi nghĩa Bạch Liên giáo ở vùng giáp ranh giữa Tứ Xuyên-Thiểm Tây-Hồ Bắc-Hà Nam'],
#   'em_score': False,
#   'f1_score': 0.717948717948718},
#  {'question': 'Thiểm Tây đã gặp thêm khó khăn gì sau khi cuộc nổi loạn Hồi giáo kết thúc?',
#   'predict': 'bị một nạn đói nghiêm trọng',
#   'ground_truths': ['bị một nạn đói nghiêm trọng do hạn hán kéo dài, tỉnh hầu như không có mưa từ năm 1876 đến năm 1878',
#    'bị một nạn đói nghiêm trọng do hạn hán kéo dài',
#    'bị một nạn đói nghiêm trọng do hạn hán kéo dài',
#    'bị một nạn đói nghiêm trọng do hạn hán kéo dài'],
#   'em_score': False,
#   'f1_score': 0.7058823529411764},
#  {'question': 'Điều gì đã cản trở nhà Thanh trong nỗ lực khắc phục khủng hoảng vào năm 1877?',
#   'predict': 'những yếu kém về hạ tầng giao thông',
#   'ground_truths': ['những yếu kém về hạ tầng giao thông',
#    'những yếu kém về hạ tầng giao thông đã cản trở hoạt động cứu trợ',
#    'những yếu kém về hạ tầng giao thông đã cản trở hoạt động cứu trợ',
#    'những yếu kém về hạ tầng giao thông đã cản trở hoạt động cứu trợ'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Số người chết vì nạn đói của nhà Thanh thời đó ước tính khoảng bao nhiêu?',
#   'predict': 'từ 4 đến 5 người',
#   'ground_truths': ['Có thể đã có từ 4 đến 5 người chết đói chỉ tính riêng ở Thiểm Tây, một số huyện trong thung lũng Vị Hà màu mỡ mất trên 100.000 người mỗi huyện',
#    '100.000 người mỗi huyện',
#    '4 đến 5 người chết đói chỉ tính riêng ở Thiểm Tây, một số huyện trong thung lũng Vị Hà màu mỡ mất trên 100.000 người mỗi huyện',
#    'Có thể đã có từ 4 đến 5 người chết đói chỉ tính riêng ở Thiểm Tây, một số huyện trong thung lũng Vị Hà màu mỡ mất trên 100.000 người mỗi huyện'],
#   'em_score': False,
#   'f1_score': 0.2631578947368421},
#  {'question': 'Những tai họa vào cuối thế kỷ XIX đã tác động như thế nào đến Thiểm Tây?',
#   'predict': 'trở thành nơi nhập cư của những người mong muốn có ruộng đất từ Tứ Xuyên và Hà Bắc',
#   'ground_truths': ['Thiểm Tây đã trở thành nơi nhập cư của những người mong muốn có ruộng đất từ Tứ Xuyên và Hà Bắc',
#    'trở thành nơi nhập cư của những người mong muốn có ruộng đất từ Tứ Xuyên và Hà Bắc',
#    'trở thành nơi nhập cư của những người mong muốn có ruộng đất từ Tứ Xuyên và Hà Bắc',
#    'trở thành nơi nhập cư của những người mong muốn có ruộng đất từ Tứ Xuyên và Hà Bắc'],
#   'em_score': True,
#   'f1_score': 1.0},
#  {'question': 'Những năm đầu thế kỷ XX, Thiểm Tây đã gặp phải nạn đói vào những năm nào?',
#   'predict': '1915, năm 1921',
#   'ground_truths': ['vào các năm 1915, năm 1921, và cuối cùng là năm 1928',
#    'bị thiệt hại từ những nạn đói định kỳ',
#    'bị thiệt hại từ những nạn đói định kỳ',
#    'bị thiệt hại từ những nạn đói định kỳ'],
#   'em_score': False,
#   'f1_score': 0.4},
#  {'question': 'Nạn đói năm 1928, đã gây ra thiệt hại như thế nào đối với Thiểm Tây?',
